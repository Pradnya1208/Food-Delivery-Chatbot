# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

from bson.objectid import ObjectId
import time
import datetime

# %%
# !pip install colorama
# Out:
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (0.4.4)

# %%
with open('intents.json') as file:
    data = json.load(file)
    
train_patterns = [] # patterns
train_intents = [] # tags
labels = [] #tags
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        train_patterns.append(pattern)
        train_intents.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
print("train_patterns :", train_patterns[100])
print("train_intents :", train_intents[100])
print("num_classes :", num_classes)
# Out:
# train_patterns : I am hungry
# train_intents : menu
# num_classes : 23

# %% [markdown]
# ### Then we use `LabelEncoder()` function provided by scikit-learn to convert the target labels into a model understandable form.

# %%
label_encoder = LabelEncoder()
label_encoder.fit(train_intents)
train_intents = label_encoder.transform(train_intents)

# %% [markdown]
# ## Vectorization
#
# - We vectorize our text data corpus by using the “Tokenizer” class and it allows us to limit our vocabulary size up to some defined number.
#
# - When we use this class for the text pre-processing task, by default all punctuations will be removed, turning the texts into space-separated sequences of words, and these sequences are then split into lists of tokens.
#
# - They will then be indexed or vectorized. We can also add “oov_token” which is a value for “out of token” to deal with out of vocabulary words(tokens) at inference time.
#
# - The “pad_sequences” method is used to make all the training text sequences into the same size.

# %%
vocab_size = 11250
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=None)
tokenizer.fit_on_texts(train_patterns)

word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(train_patterns)

padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
print("train_patterns :", train_patterns[99])
print("sequences: ", sequences[99])
# Out:
# train_patterns : Im damn hungry
# sequences:  [204, 205, 128]

# %% [markdown]
# ## 1) Here, we have to deal with multiple inputs or multiple outputs. Hence, we'll use `Keras` `Sequential()` model.
#
# read more : [Kears Sequential model details](https://keras.io/guides/sequential_model/)
#
# ## 2) Loss Function: `sparse_categorical_crossentropy` : We are using this crossentropy loss function when there are two or more label classes.
# read more about [sparse_categorical_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            180000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 23)                391
#
# =================================================================
# Total params: 180,935
# Trainable params: 180,935
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(train_intents), epochs=epochs)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 3ms/step - loss: 3.1325 - accuracy: 0.0650
# Epoch 2/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1243 - accuracy: 0.0732
# Epoch 3/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1160 - accuracy: 0.0678
# Epoch 4/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1057 - accuracy: 0.0732
# Epoch 5/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0936 - accuracy: 0.1111
# Epoch 6/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0781 - accuracy: 0.1355
# Epoch 7/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0592 - accuracy: 0.1301
# Epoch 8/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0350 - accuracy: 0.1301
# Epoch 9/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0075 - accuracy: 0.1301
# Epoch 10/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9802 - accuracy: 0.1301
# Epoch 11/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9493 - accuracy: 0.1301
# Epoch 12/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9239 - accuracy: 0.1301
# Epoch 13/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9050 - accuracy: 0.1301
# Epoch 14/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8878 - accuracy: 0.1301
# Epoch 15/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8719 - accuracy: 0.1301
# Epoch 16/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8568 - accuracy: 0.1301
# Epoch 17/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8432 - accuracy: 0.1328
# Epoch 18/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8299 - accuracy: 0.1328
# Epoch 19/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8158 - accuracy: 0.1409
# Epoch 20/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8011 - accuracy: 0.1436
# Epoch 21/500
# 12/12 [==============================] - ETA: 0s - loss: 2.7681 - accuracy: 0.09 - 0s 3ms/step - loss: 2.7841 - accuracy: 0.1436
# Epoch 22/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7657 - accuracy: 0.1463
# Epoch 23/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7453 - accuracy: 0.1491
# Epoch 24/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7249 - accuracy: 0.1518
# Epoch 25/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6999 - accuracy: 0.1572
# Epoch 26/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6749 - accuracy: 0.1680
# Epoch 27/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6482 - accuracy: 0.1707
# Epoch 28/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6187 - accuracy: 0.1734
# Epoch 29/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5860 - accuracy: 0.1762
# Epoch 30/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5546 - accuracy: 0.1762
# Epoch 31/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5208 - accuracy: 0.1843
# Epoch 32/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4889 - accuracy: 0.1897
# Epoch 33/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4561 - accuracy: 0.1978
# Epoch 34/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4236 - accuracy: 0.2060
# Epoch 35/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3931 - accuracy: 0.2168
# Epoch 36/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3594 - accuracy: 0.2358
# Epoch 37/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3263 - accuracy: 0.2493
# Epoch 38/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2930 - accuracy: 0.2575
# Epoch 39/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2595 - accuracy: 0.2791
# Epoch 40/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2257 - accuracy: 0.2900
# Epoch 41/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1948 - accuracy: 0.2981
# Epoch 42/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1618 - accuracy: 0.3225
# Epoch 43/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1249 - accuracy: 0.3198
# Epoch 44/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.0904 - accuracy: 0.3306
# Epoch 45/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.0557 - accuracy: 0.3388
# Epoch 46/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.0217 - accuracy: 0.3279
# Epoch 47/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9851 - accuracy: 0.3333
# Epoch 48/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9530 - accuracy: 0.3659
# Epoch 49/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9219 - accuracy: 0.3442
# Epoch 50/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8958 - accuracy: 0.3794
# Epoch 51/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8579 - accuracy: 0.3794
# Epoch 52/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8286 - accuracy: 0.3902
# Epoch 53/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7946 - accuracy: 0.3875
# Epoch 54/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7672 - accuracy: 0.3930
# Epoch 55/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7353 - accuracy: 0.4146
# Epoch 56/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7079 - accuracy: 0.4282
# Epoch 57/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.6797 - accuracy: 0.4444
# Epoch 58/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.6502 - accuracy: 0.4553
# Epoch 59/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.6252 - accuracy: 0.4363
# Epoch 60/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5944 - accuracy: 0.4661
# Epoch 61/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5685 - accuracy: 0.4851
# Epoch 62/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5414 - accuracy: 0.5095
# Epoch 63/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5136 - accuracy: 0.5339
# Epoch 64/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4891 - accuracy: 0.5122
# Epoch 65/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4686 - accuracy: 0.5122
# Epoch 66/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4384 - accuracy: 0.5393
# Epoch 67/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4109 - accuracy: 0.5718
# Epoch 68/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3878 - accuracy: 0.5637
# Epoch 69/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3590 - accuracy: 0.5989
# Epoch 70/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3383 - accuracy: 0.5962
# Epoch 71/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3194 - accuracy: 0.5799
# Epoch 72/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2869 - accuracy: 0.6125
# Epoch 73/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2640 - accuracy: 0.6287
# Epoch 74/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2419 - accuracy: 0.6423
# Epoch 75/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2177 - accuracy: 0.6477
# Epoch 76/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1946 - accuracy: 0.6640
# Epoch 77/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1711 - accuracy: 0.6640
# Epoch 78/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1491 - accuracy: 0.6667
# Epoch 79/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1265 - accuracy: 0.6856
# Epoch 80/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1063 - accuracy: 0.7019
# Epoch 81/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0833 - accuracy: 0.7100
# Epoch 82/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0626 - accuracy: 0.7073
# Epoch 83/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0421 - accuracy: 0.7182
# Epoch 84/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0222 - accuracy: 0.7317
# Epoch 85/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0030 - accuracy: 0.7209
# Epoch 86/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9859 - accuracy: 0.7344
# Epoch 87/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9672 - accuracy: 0.7154
# Epoch 88/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9450 - accuracy: 0.7425
# Epoch 89/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9276 - accuracy: 0.7398
# Epoch 90/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9095 - accuracy: 0.7615
# Epoch 91/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8903 - accuracy: 0.7615
# Epoch 92/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8743 - accuracy: 0.7534
# Epoch 93/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8547 - accuracy: 0.7940
# Epoch 94/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8408 - accuracy: 0.7832
# Epoch 95/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8234 - accuracy: 0.7913
# Epoch 96/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8097 - accuracy: 0.7886
# Epoch 97/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7933 - accuracy: 0.7832
# Epoch 98/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7836 - accuracy: 0.7995
# Epoch 99/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7623 - accuracy: 0.8184
# Epoch 100/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7489 - accuracy: 0.8157
# Epoch 101/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7373 - accuracy: 0.8293
# Epoch 102/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7207 - accuracy: 0.8293
# Epoch 103/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7056 - accuracy: 0.8293
# Epoch 104/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6964 - accuracy: 0.8455
# Epoch 105/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6844 - accuracy: 0.8482
# Epoch 106/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6728 - accuracy: 0.8482
# Epoch 107/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6616 - accuracy: 0.8347
# Epoch 108/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6501 - accuracy: 0.8428
# Epoch 109/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.8347
# Epoch 110/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6280 - accuracy: 0.8428
# Epoch 111/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6205 - accuracy: 0.8645
# Epoch 112/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6037 - accuracy: 0.8672
# Epoch 113/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5930 - accuracy: 0.8591
# Epoch 114/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.8699
# Epoch 115/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.8726
# Epoch 116/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5634 - accuracy: 0.8780
# Epoch 117/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5546 - accuracy: 0.8835
# Epoch 118/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.8862
# Epoch 119/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.8835
# Epoch 120/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5276 - accuracy: 0.8889
# Epoch 121/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5192 - accuracy: 0.8889
# Epoch 122/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5097 - accuracy: 0.9024
# Epoch 123/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5028 - accuracy: 0.9079
# Epoch 124/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4926 - accuracy: 0.8997
# Epoch 125/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4846 - accuracy: 0.8997
# Epoch 126/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4765 - accuracy: 0.9133
# Epoch 127/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4686 - accuracy: 0.9160
# Epoch 128/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.9241
# Epoch 129/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4579 - accuracy: 0.9133
# Epoch 130/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4467 - accuracy: 0.9187
# Epoch 131/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4397 - accuracy: 0.9295
# Epoch 132/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.9268
# Epoch 133/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4224 - accuracy: 0.9322
# Epoch 134/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4170 - accuracy: 0.9377
# Epoch 135/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4093 - accuracy: 0.9350
# Epoch 136/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4053 - accuracy: 0.9322
# Epoch 137/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3975 - accuracy: 0.9350
# Epoch 138/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.9458
# Epoch 139/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.9458
# Epoch 140/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.9377
# Epoch 141/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.9458
# Epoch 142/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.9458
# Epoch 143/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3560 - accuracy: 0.9539
# Epoch 144/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.9485
# Epoch 145/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3461 - accuracy: 0.9485
# Epoch 146/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3377 - accuracy: 0.9512
# Epoch 147/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3322 - accuracy: 0.9621
# Epoch 148/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3263 - accuracy: 0.9566
# Epoch 149/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3196 - accuracy: 0.9621
# Epoch 150/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3159 - accuracy: 0.9593
# Epoch 151/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3083 - accuracy: 0.9593
# Epoch 152/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3047 - accuracy: 0.9675
# Epoch 153/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2996 - accuracy: 0.9648
# Epoch 154/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2933 - accuracy: 0.9675
# Epoch 155/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2880 - accuracy: 0.9648
# Epoch 156/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2838 - accuracy: 0.9648
# Epoch 157/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2778 - accuracy: 0.9648
# Epoch 158/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.9648
# Epoch 159/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2694 - accuracy: 0.9729
# Epoch 160/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2644 - accuracy: 0.9675
# Epoch 161/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2594 - accuracy: 0.9702
# Epoch 162/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2544 - accuracy: 0.9729
# Epoch 163/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2493 - accuracy: 0.9783
# Epoch 164/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2454 - accuracy: 0.9783
# Epoch 165/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9783
# Epoch 166/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9810
# Epoch 167/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2305 - accuracy: 0.9810
# Epoch 168/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9810
# Epoch 169/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.9837
# Epoch 170/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.9810
# Epoch 171/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.9810
# Epoch 172/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2115 - accuracy: 0.9810
# Epoch 173/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2067 - accuracy: 0.9810
# Epoch 174/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2038 - accuracy: 0.9810
# Epoch 175/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.9810
# Epoch 176/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1972 - accuracy: 0.9810
# Epoch 177/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.9810
# Epoch 178/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1898 - accuracy: 0.9810
# Epoch 179/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9837
# Epoch 180/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1824 - accuracy: 0.9837
# Epoch 181/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1784 - accuracy: 0.9810
# Epoch 182/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1752 - accuracy: 0.9837
# Epoch 183/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1716 - accuracy: 0.9837
# Epoch 184/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1685 - accuracy: 0.9837
# Epoch 185/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1658 - accuracy: 0.9837
# Epoch 186/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1669 - accuracy: 0.9837
# Epoch 187/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1600 - accuracy: 0.9864
# Epoch 188/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.9864
# Epoch 189/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1521 - accuracy: 0.9837
# Epoch 190/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1495 - accuracy: 0.9864
# Epoch 191/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1474 - accuracy: 0.9864
# Epoch 192/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 0.9864
# Epoch 193/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1409 - accuracy: 0.9864
# Epoch 194/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1380 - accuracy: 0.9864
# Epoch 195/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9892
# Epoch 196/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9864
# Epoch 197/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9892
# Epoch 198/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1292 - accuracy: 0.9864
# Epoch 199/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9864
# Epoch 200/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.9864
# Epoch 201/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1210 - accuracy: 0.9892
# Epoch 202/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.9892
# Epoch 203/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1179 - accuracy: 0.9892
# Epoch 204/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1162 - accuracy: 0.9919
# Epoch 205/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1127 - accuracy: 0.9892
# Epoch 206/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1107 - accuracy: 0.9919
# Epoch 207/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9919
# Epoch 208/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9919
# Epoch 209/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9892
# Epoch 210/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.9892
# Epoch 211/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.9946
# Epoch 212/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.9946
# Epoch 213/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9946
# Epoch 214/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 0.9946
# Epoch 215/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 0.9946
# Epoch 216/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.9946
# Epoch 217/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0884 - accuracy: 0.9946
# Epoch 218/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0871 - accuracy: 0.9946
# Epoch 219/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0858 - accuracy: 0.9946
# Epoch 220/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9946
# Epoch 221/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9946
# Epoch 222/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9946
# Epoch 223/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9946
# Epoch 224/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9946
# Epoch 225/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9946
# Epoch 226/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9973
# Epoch 227/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 0.9973
# Epoch 228/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0719 - accuracy: 0.9946
# Epoch 229/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0703 - accuracy: 0.9973
# Epoch 230/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0693 - accuracy: 0.9973
# Epoch 231/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 0.9973
# Epoch 232/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9973
# Epoch 233/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0654 - accuracy: 0.9973
# Epoch 234/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9973
# Epoch 235/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0629 - accuracy: 0.9973
# Epoch 236/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0617 - accuracy: 0.9973
# Epoch 237/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0608 - accuracy: 0.9973
# Epoch 238/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9973
# Epoch 239/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9973
# Epoch 240/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 0.9973
# Epoch 241/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 242/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 243/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 244/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 0.9973
# Epoch 245/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9973
# Epoch 246/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0521 - accuracy: 0.9973
# Epoch 247/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 0.9973
# Epoch 248/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 249/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 250/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 251/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 252/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 253/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 254/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0449 - accuracy: 1.0000
# Epoch 255/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 256/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 257/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 258/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 259/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 260/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 261/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 262/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 263/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 264/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 265/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 266/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 267/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 268/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 269/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 270/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 271/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 272/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 273/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 274/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 275/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 276/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 277/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 278/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 279/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 280/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 281/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 282/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 283/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 284/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 285/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 286/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 287/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 288/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 289/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 290/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 291/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 292/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 293/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 294/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 295/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 296/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 297/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 298/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 299/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 300/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 301/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 302/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 303/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 304/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 305/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 306/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 307/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 308/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 309/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 310/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 311/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 312/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 313/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 314/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 315/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 316/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 317/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 318/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 319/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 320/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 321/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 322/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 323/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 324/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 325/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 326/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 327/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 328/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 329/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 330/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 331/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 332/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 333/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 334/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 335/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 336/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 337/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 338/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 339/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 340/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 341/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 342/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 343/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 344/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 345/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 346/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 347/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 348/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 349/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 350/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 351/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 352/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 353/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 354/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 355/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 356/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 357/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 358/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 359/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 360/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 361/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 362/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 363/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 364/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 365/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 366/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 367/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 368/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 369/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 370/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 371/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 372/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 373/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 374/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 375/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 376/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 377/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 378/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 379/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 380/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 381/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 382/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 383/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 384/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 385/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 386/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 387/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 388/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 389/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 390/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 391/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 392/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 393/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 394/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 395/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 396/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 397/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 398/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 399/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 400/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 401/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 402/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 403/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 404/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 405/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 406/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 407/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 408/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 409/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 410/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 411/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 412/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 413/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 414/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 415/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 416/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 417/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 418/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 419/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 420/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 421/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 422/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 423/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 424/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 425/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 426/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 427/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 428/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 429/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 430/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 431/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 432/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 433/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 434/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 435/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 436/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 437/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 438/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 439/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 440/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 441/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 442/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 443/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 444/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 445/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 446/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 447/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 448/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 449/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 450/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 451/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 452/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 453/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 454/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 455/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 456/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 457/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 458/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 459/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 460/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 461/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 462/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 463/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 464/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 465/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 466/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 467/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 468/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 469/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 470/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 471/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 472/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 473/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 474/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 475/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 476/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 477/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 478/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 479/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 480/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 481/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 482/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 483/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 484/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 485/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 486/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 487/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 488/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 489/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 490/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 491/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 492/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 493/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 494/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 495/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 496/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 497/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 498/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 499/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 500/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000

# %%
history_dict = history.history

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")


loss_values = history_dict['loss']
#val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
#plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
#val_accuracy_values=history_dict['val_accuracy']
#plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred = model.predict(padded_sequences)
y_result=[]
for i in y_pred:
    max_value = max(i)
    #print(max_value)
    y_result.append(np.where(i == max_value)[0][0])





from sklearn.metrics import confusion_matrix
#CM matrix for training data
plt.figure(figsize=(12,12))

matrix_nn = confusion_matrix(y_result, np.array(train_intents))

sns.heatmap(matrix_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ## Save the models
#
# We are saving 3 different things separately
# - Classification model
# - fitted Tokenizer object
# - fitted label encoder object

# %%
# saving model
model.save("chat_model")

import pickle

# saving tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

# saving label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(label_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model\assets

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\admin\anaconda3\lib\site-packages (4.0.1)

# %%
import json
import random
import datetime
import pymongo
import uuid

# %%
seat_count = 50
import urllib.parse
# Make sure Settings->Network Access has correct settings

password=urllib.parse.quote_plus("<password>")
database = urllib.parse.quote_plus("<database name>")

URI= "mongodb+srv://<hostname>:" + password + "@cluster0.jpcjh.mongodb.net/" + database + "?" + "retryWrites=true&w=majority"
#client = pymongo.MongoClient(URI)
client = pymongo.MongoClient(URI, connect=False)

db = client["<databasename>"]
menu_collection = db["menu"]
feedback_collection = db["feedback"]
order_collection=db["Orders"]
bookings_collection = db["bookings"]

# %%
query = {"mainmenu": "Y"}

veg_data = menu_collection.find(query)
x=[]
for i in veg_data:
    if (i.get("breakfast")=="N") == True:
        x.append(i.get("item"))
x
# Out:
# ['Soups',
#  'Starters',
#  'Main Course',
#  'Snacks',
#  'Snacks',
#  'Breakfast',
#  'accompaniments']

# %%
# Order
def record_order(message):
    print("Saving customers order")
    print(message)
    items_ = message.split("||")


    arr_dict={}
    for j,i in enumerate(items_[1:-1]):
 
        str1_ = i.split(",")
        dict_name='item {}'.format(j)
        arr_dict[dict_name]={}
    
        arr_dict[dict_name]['item'] = str1_[0].split(":")[1]
        arr_dict[dict_name]['price'] = str1_[1].split(":")[1]
        arr_dict[dict_name]['quantity'] = str1_[2].split(":")[1]
        #print(arr_dict[dict_name])
    

    
    arr_dict["Total Price"]={}
    arr_dict["order_details"]={}
         
    orderplaced_id = str(uuid.uuid4())
    arr_dict["Total Price"]["total bill"] = items_[0].split(":")[1]
    arr_dict["order_details"]["OrderID"] = orderplaced_id
    
    # Adding the ordering time:
    now_ = datetime.datetime.now()
    booking_time_ = now_.strftime("%Y-%m-%d %H:%M:%S")
    arr_dict["order_details"]["OrderTime"] = booking_time_
    arr_dict["order_details"]["OrderStatus"]="placed"
   
    
    
    
    # Make the array of nested dictionary
    item_dict=[]
    item_dict.append(arr_dict)
    
    nested_dictionary =item_dict
    order_collection.insert_many(nested_dictionary)
    return orderplaced_id
    # get the order id
    
    
    
# Cancel Order
def cancel_order(order_id):
    print(order_id)
    result={}
    status_=""
    query = {"order_details.OrderID": order_id}
    doc_ = order_collection.find(query)
    
    for x in doc_:
        result = x
        
    print(result)
    
    
   
        
    if result:
        status_=result["order_details"]["OrderStatus"]
        od_id = result["_id"]
        print(od_id)
        print(status_)
        if status_ == 'placed':
            


            order_itemX=['Total Price','_id','order_details', 'OrderStatus']
            cancelStr = "Cancelling your order with : "
            for i in result:
                if i not in order_itemX:
                    cancelStr+= "("+result[i]['quantity'] + "-" + result[i]['item'] + ") "
            
   
            cancelStr+="💰 ₹" + result['Total Price']['total bill'] + " will be refunded to your account."
            
           
            order_collection.replace_one({"_id" :od_id },  {"order_details":{"OrderID":order_id,"OrderStatus":"canceled"}})
            update_data = order_collection.find_one({"_id":od_id})
            print(update_data["order_details"]["OrderStatus"])
            
            return cancelStr
        
        else:
            return "🚫 This order has been canceled already."
    
    else:
        return "Please enter correct Order ID and 📌before entering order ID send the 'cancel Order' message again." 


# Order Status


def order_status(order_id):
    making = "00:05:00"
    made = "00:20:00"
    delivery = "00:35:00"
    
    print(order_id)
    result={}
    order_status=""
    status_=""
    query = {"order_details.OrderID": order_id}
    doc_ = order_collection.find(query)
    
    for x in doc_:
        result = x
        
    print(result)

    if result:
        status_=result["order_details"]["OrderStatus"]
        od_id = result["_id"]
        print(od_id)
        print(status_)
        if status_ == 'placed':
            order_t = datetime.datetime.strptime(result["order_details"]["OrderTime"].split(" ")[1], "%H:%M:%S")
            seconds_ = (datetime.datetime.now() - order_t).seconds
            time_gap = time.strftime("%H:%M:%S", time.gmtime(seconds_))
            
            #> 20 minutes
            if (datetime.datetime.strptime(time_gap, "%H:%M:%S") > datetime.datetime.strptime(made, "%H:%M:%S")) and (datetime.datetime.strptime(time_gap, "%H:%M:%S") < datetime.datetime.strptime(delivery, "%H:%M:%S")):
                order_status = "Your order is on the way. 🚀"

            #between 5-20 minutes
            elif (datetime.datetime.strptime(time_gap, "%H:%M:%S") <= datetime.datetime.strptime(made, "%H:%M:%S")) and (datetime.datetime.strptime(time_gap, "%H:%M:%S") > datetime.datetime.strptime(making, "%H:%M:%S")):
                order_status = "Your food is being prepared. 🍜"
                
            #<5 minutes
            elif datetime.datetime.strptime(time_gap, "%H:%M:%S") < datetime.datetime.strptime(making, "%H:%M:%S"):
                order_status = "You order has been placed and chef is about to start cooking. 👩‍🍳"

            #>35 minutes
            elif datetime.datetime.strptime(time_gap, "%H:%M:%S") > datetime.datetime.strptime(delivery, "%H:%M:%S"):
                order_status = "We regret for delay in your food delivery, please contact our delivery agent or ask for refund.We assure you of speedy and safe delivery nect time. 🙏"
    
            else:
                order_status = "Food is already delivered.🍱"
            
            
            

            return order_status
        
        else:
            return "🚫 This order has been canceled already."
    
    else:
        return "Please enter correct Order ID and 📌before entering order ID send the 'Order Status' message again." 


 
    
    
# Book a table:
seat_count = 50
def book_table():
    global seat_count
    seat_count = seat_count - 1
    booking_id = str(uuid.uuid4())
    now = datetime.datetime.now()
    booking_time = now.strftime("%Y-%m-%d %H:%M:%S")
    booking_doc = {"booking_id": booking_id, "booking_time": booking_time}
    bookings_collection.insert_one(booking_doc)
    return booking_id


def get_specific_response(tag):
    for intent in data['intents']:
        if intent['tag'] == tag:
            responses = intent['responses']
    response = random.choice(responses)
    return response


def show_menu():
    all_items = menu_collection.distinct('item')
    response = ', '.join(all_items)
    return response

def record_feedback(message, type):
    print("Recording your feedback")
    feedback_doc = {"feedback_string": message, "type": type}
    feedback_collection.insert_one(feedback_doc)
    
def recipe_enquiry(inp):
    response=""
    for i in menu_collection.distinct('item'):
        if i.lower() in inp.lower():
            #print(i)
            #if inp.lower()== i.lower():
        
            query_about= {"item":i}
            about = menu_collection.find(query_about)
            for j in about:
                response = j.get("details")
        
            
    if response =="":
        response = "I don't know much about this recipe! But, you can contact our restaurant for more details."
    return response


def suggest():
    day = datetime.datetime.now()
    day = day.strftime("%A")
    if day == "Monday":
        response = "I would recommend: Paneer Roll and Chicken Biryani"
    elif day == "Tuesday":
        response = "I would recommend: Cheese Grilled Sandwich and Chicken tripple rice"

    elif day == "Wednesday":
        response = "I would recommend: Egg Roll and Latte "

    elif day == "Thursday":
        response = "I would recommend: Mixed Fruit Juice and Chicken cheese sandwich"

    elif day == "Friday":
        response = "I would recommend: White Sauce Pasta and Cheese cake"

    elif day == "Saturday":
        response = "I would recommend: Chicken Roll and cold coffee"

    elif day == "Sunday":
        response = "I would recommend: Schezwan Rice and Manchurian"
    return response


def veg_menu():
    res=[]    
    query = {"veg": "Y"}
    b_query = {"Breads": "Y"}
    d_query = {"Desert": "Y"}
    i_query = {"icecreams_bev":"Y"}
    breads=[]
    deserts =[]
    ice_bev=[]


    b_doc = menu_collection.find(b_query)
    for x in b_doc:
        breads.append(x.get("item"))
    
    d_doc = menu_collection.find(d_query)
    for x in d_doc:
        deserts.append(x.get("item"))
    
    i_doc = menu_collection.find(i_query)
    for x in i_doc:
        ice_bev.append(x.get("item")) 
        
        
    veg_doc = menu_collection.find(query)
    for x in veg_doc:
        if x.get("item") not in exclude_items:
            res.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        
        
    return res



def nonveg_menu():
    re=[]
    query = {"nonveg": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        re.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return re




def breakfast_menu():
    br=[]
    query = {"breakfast": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        br.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return br

def bevrages_menu():
    bev=[]
    query = {"icecreams_bev": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        bev.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return bev

def desert_menu():
    de=[]
    query = {"Desert": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        de.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return de

def snacks_menu():
    sn=[]
    query = {"snacks": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        sn.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return sn


def main_menu():
    menu=[]
    query = {"mainmenu": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        menu.append(str(x.get("item")) +"\n")
   
    return menu

def offers():
    
    response = "Sorry there are no offers available now."
    return response

# %%
def generate_response(tag, user_input):
    global seat_count
    #tag = get_intent(message)
    response = ""
    if tag != "":
        if tag == "book_table":

            if seat_count > 0:
                booking_id = book_table()
                response = "Your table has been booked successfully :" + str(
                    booking_id)
            else:
                response = "Sorry we are sold out now!"


        elif tag == "available_tables":
            response = "Right now, there are " + str(seat_count) + " table(s) available."

        elif tag == "veg_enquiry":
            response ="Hey, You can discover our amazing vegetarian options in the Menu section on your left."

        elif tag == "nonveg_enquiry":
            response = "Hey, You can discover Non-vegetarian food options in the Menu section on your left."
            
        elif tag == "vegan_enquiry":
            response = "Sorry, We don't serve Vegan Food"

        elif tag == "offers":
            response =offers()

        elif tag == "suggest":
            
            response =suggest()
            response+="\n"+"Or else you can check our populars in the Menu section!!"

        elif tag == "recipe_enquiry":
            response =recipe_enquiry(user_input)

        elif tag == "menu":
            response="Checkout our lip-smacking food options on your left. Just add whichever food item you like." + "\n" + "worried about recipes and ingredients? ask me!!. I've got you covered 😎"
            
        elif tag == "Icecreams_bevrages":
            response = "Checkout Desserts option for the refreshing bevrages!! 🍨"
            
        elif tag == "Quick_Bites":
            #response1 = snacks_menu()
            #response2= breakfast_menu()
            #response3 = bevrages_menu()
            #response = response1 + response2 + response3
            response = "Hey, You can explore breakfast, Snacks and Desserts options on your left for some quick refreshments!!"
            
        elif tag == "positive_feedback":
            record_feedback(user_input, "positive")
            response = "Huzzah!!😍 Thank you so much for your valuable feedback. We look forward to serving you again!"

        elif "negative_feedback" == tag:
            record_feedback(user_input, "negative")
            response = "Thank you so much for your valuable feedback. We deeply regret the inconvenience. We have " \
                       "forwarded your concerns to the authority and hope to satisfy you better the next time! 🙏"
        # for other intents with pre-defined responses that can be pulled from dataset
        else:
            response = get_specific_response(tag)
    else:
        response = "Sorry! I didn't get it, please try to be more precise."
    return response

# %% [markdown]
# ### Load the model

# %%
def response_gen(message):
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([message]),truncating='post', maxlen=max_len))
    
    ## Find the intent
    tag = lbl_encoder.inverse_transform([np.argmax(result)])
    print(tag)

    for i in data['intents']:
        if i['tag'] == tag:
            output = generate_response(tag, message)
            
    return output

# %%
from flask import Flask, render_template, request, jsonify
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
import os

ORDER_ID=False

TEMPLATE_DIR = os.path.abspath('./templates')
STATIC_DIR = os.path.abspath('./static')

app = Flask(__name__) #


@app.route('/')
def index():
    return render_template('index.html')


@app.route('/get')
def get_bot_response():
    
    message = request.args.get('msg')
    #print(message)
    response = ""
    if message:
        if message.startswith("TotalPrice:"):
            print(message)
            o_id = record_order(message)
            id_res = "Your Order ID is : " + o_id + " Kindly remember this ID for the future reference."
            return id_res
        #Order Cancel
        elif message.endswith("-ORDERID"):
            # if intent is Cancel
            print(message)
            
            cancelOrderStr = cancel_order(message.split("-ORDERID")[0])
            
            return cancelOrderStr
        
        elif message.endswith("-STATUSID"):
            # if intent is Cancel
            print(message)
            
            statusOrderStr = order_status(message.split("-STATUSID")[0])
            
            return statusOrderStr
            
            
            
        else:
            response = response_gen(message)
            #print(response)
            
                
        
        return str(response)
    
    else:
        return "Missing Data!"
    


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Feb/2022 14:15:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Feb/2022 14:15:27] "GET /style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Feb/2022 14:15:28] "GET /script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Feb/2022 14:15:28] "GET /script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Feb/2022 14:15:37] "GET /style.css HTTP/1.1" 404 -

# %% [markdown]
# Mongodb reference: https://kb.objectrocket.com/category/mongo-db
